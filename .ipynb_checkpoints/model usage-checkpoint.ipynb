# %%
from joblib import dump,load
import numpy as np
model=load("ML_Project1.joblib")

# %%
input=np.array([[ 0.52127104, -0.49254597,  1.03209898,  3.69829952,  0.97731377,
       -0.56927972,  0.7467603 , -1.26749256,  1.63942936,  1.51773323,
        0.80479757, -0.07708232, -0.54251328]])
model.predict(input)
# Out:
# array([46.336])
